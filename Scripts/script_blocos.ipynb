# %% [markdown]
# <p align="left">
#   <img src="https://wp.ufc.br/assets/sitiomodelo/brasao-2.png" alt="Imagen1" width="50"/>
#   <img src="https://mmq.ufc.br/wp-content/uploads/2019/04/mmq-logo-oficial.png" alt="Imagen2" width="160"/>
# </p>
#
# ## **Universidade Federal do Ceará**
# ### **Mestrado em Modelagem e Métodos Quantitativos**
# ## **Carlos Gutiérrez**
# ---

# %%
'''
Script que divide em blocos de pixels de uma imagem maior
'''

from PIL import Image
import os
import math

Image.MAX_IMAGE_PIXELS = None

def chip_y_convertir_tif(ruta_entrada, ruta_salida=None, tamano_chip=256, superposicion=0, formato_salida='PNG'):
    """
    Divide una imagen TIF grande en piezas más pequeñas y las convierte a PNG/JPG

    Args:
        ruta_entrada (str): Ruta al archivo TIF de entrada
        ruta_salida (str): Ruta al directorio de salida (opcional)
        tamano_chip (int): Tamaño de cada chip (ancho y alto)
        superposicion (int): Superposición entre chips adyacentes en píxeles
        formato_salida (str): Formato de salida ('PNG' o 'JPEG')
    """
    # Crear directorio de salida
    if ruta_salida is None:
        # Si no se especifica ruta de salida, crear directorio basado en el nombre del archivo
        nombre_base = os.path.splitext(os.path.basename(ruta_entrada))[0]
        directorio_salida = f"{nombre_base}_chips"
    else:
        # Usar la ruta de salida especificada
        directorio_salida = ruta_salida
        nombre_base = os.path.splitext(os.path.basename(ruta_entrada))[0]

    os.makedirs(directorio_salida, exist_ok=True)

    # Abrir y convertir a RGB si es necesario
    img = Image.open(ruta_entrada)
    if img.mode != 'RGB':
        img = img.convert('RGB')

    ancho, alto = img.size

    # Calcular número de chips en cada dimensión
    tamano_chip_efectivo = tamano_chip - superposicion
    num_columnas = math.ceil(ancho / tamano_chip_efectivo)
    num_filas = math.ceil(alto / tamano_chip_efectivo)

    chips_creados = 0

    # Extraer chips
    for fila in range(num_filas):
        for columna in range(num_columnas):
            # Calcular coordenadas del chip
            izquierda = columna * tamano_chip_efectivo
            arriba = fila * tamano_chip_efectivo
            derecha = min(izquierda + tamano_chip, ancho)
            abajo = min(arriba + tamano_chip, alto)

            # Extraer chip
            chip = img.crop((izquierda, arriba, derecha, abajo))

            # Saltar chips más pequeños que el tamaño deseado
            if chip.size[0] < tamano_chip or chip.size[1] < tamano_chip:
                continue

            # Guardar chip
            ruta_salida = os.path.join(
                directorio_salida,
                f"{nombre_base}_chip_{fila}_{columna}.{formato_salida.lower()}"
            )
            chip.save(ruta_salida, formato_salida)
            chips_creados += 1

            print(f"Chip creado {chips_creados}: {ruta_salida}")

    print(f"\n¡Completado! Se crearon {chips_creados} chips en {directorio_salida}")

# %%
'''
Execução da função
'''

# Ejemplo de uso
chip_y_convertir_tif(
    ruta_entrada = '../pesquisa/data_raster_final/ortofoto_fortaleza_plazaleoes.tif',
    ruta_salida = '../pesquisa/chips_256_256/chips_plazaleoes',  # Especificar directorio de salida
    tamano_chip = 256,    # Tamaño de cada chip
    superposicion = 0,    # Superposición entre chips
    formato_salida = 'PNG'
)
# Out:
# Chip creado 1: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_0_0.png
# Chip creado 2: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_0_1.png
# Chip creado 3: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_0_2.png
# Chip creado 4: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_0_3.png
# Chip creado 5: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_0_4.png
# Chip creado 6: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_0_5.png
# Chip creado 7: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_0_6.png
# Chip creado 8: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_0_7.png
# Chip creado 9: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_0_8.png
# Chip creado 10: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_0_9.png
# Chip creado 11: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_1_0.png
# Chip creado 12: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_1_1.png
# Chip creado 13: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_1_2.png
# Chip creado 14: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_1_3.png
# Chip creado 15: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_1_4.png
# Chip creado 16: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_1_5.png
# Chip creado 17: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_1_6.png
# Chip creado 18: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_1_7.png
# Chip creado 19: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_1_8.png
# Chip creado 20: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_1_9.png
# Chip creado 21: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_2_0.png
# Chip creado 22: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_2_1.png
# Chip creado 23: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_2_2.png
# Chip creado 24: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_2_3.png
# Chip creado 25: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_2_4.png
# Chip creado 26: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_2_5.png
# Chip creado 27: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_2_6.png
# Chip creado 28: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_2_7.png
# Chip creado 29: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_2_8.png
# Chip creado 30: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_2_9.png
# Chip creado 31: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_3_0.png
# Chip creado 32: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_3_1.png
# Chip creado 33: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_3_2.png
# Chip creado 34: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_3_3.png
# Chip creado 35: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_3_4.png
# Chip creado 36: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_3_5.png
# Chip creado 37: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_3_6.png
# Chip creado 38: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_3_7.png
# Chip creado 39: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_3_8.png
# Chip creado 40: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_3_9.png
# Chip creado 41: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_4_0.png
# Chip creado 42: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_4_1.png
# Chip creado 43: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_4_2.png
# Chip creado 44: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_4_3.png
# Chip creado 45: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_4_4.png
# Chip creado 46: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_4_5.png
# Chip creado 47: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_4_6.png
# Chip creado 48: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_4_7.png
# Chip creado 49: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_4_8.png
# Chip creado 50: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_4_9.png
# Chip creado 51: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_5_0.png
# Chip creado 52: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_5_1.png
# Chip creado 53: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_5_2.png
# Chip creado 54: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_5_3.png
# Chip creado 55: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_5_4.png
# Chip creado 56: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_5_5.png
# Chip creado 57: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_5_6.png
# Chip creado 58: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_5_7.png
# Chip creado 59: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_5_8.png
# Chip creado 60: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_5_9.png
# Chip creado 61: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_6_0.png
# Chip creado 62: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_6_1.png
# Chip creado 63: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_6_2.png
# Chip creado 64: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_6_3.png
# Chip creado 65: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_6_4.png
# Chip creado 66: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_6_5.png
# Chip creado 67: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_6_6.png
# Chip creado 68: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_6_7.png
# Chip creado 69: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_6_8.png
# Chip creado 70: ../pesquisa/chips_256_256/chips_plazaleoes\ortofoto_fortaleza_plazaleoes_chip_6_9.png
#
# ¡Completado! Se crearon 70 chips en ../pesquisa/chips_256_256/chips_plazaleoes
